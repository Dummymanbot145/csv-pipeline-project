# %%
# Cell 1 - Simple display
# Principle: Simplicity

from IPython.display import display, HTML

display(HTML("""
    <div style='background:#1e1e2e; padding:30px; text-align:center'>
        <h2 style='color:white'>CSV File Pipeline</h2>
        <p style='color:#aaaaaa'>Monitor your FTP file downloads</p>
    </div>
"""))

# %%
# Cell 2 - Buttons and status
# Principle: Feedback

from IPython.display import display, HTML

display(HTML("""
    <div style='background:#1e1e2e; padding:20px; text-align:center'>
        <h3 style='color:white'>CSV File Pipeline</h3>
        <p style='color:#4fc3f7'>Status: Running...</p>
        <button style='background:#4caf50; color:white; padding:8px 20px;
                border:none; margin:5px; font-size:14px'>▶ Start</button>
        <button style='background:#ef5350; color:white; padding:8px 20px;
                border:none; margin:5px; font-size:14px'>■ Stop</button>
    </div>
"""))

# %%
# Cell 3 - Colour coded results log
# Principle: Visibility

from IPython.display import display, HTML

display(HTML("""
    <div style='background:#1e1e2e; padding:20px'>
        <h3 style='color:white; text-align:center'>CSV File Pipeline</h3>
        <p style='color:#4caf50'>Status: Done!</p>

        <b style='color:white'>Results</b>
        <div style='background:#2e2e3e; padding:10px; margin-top:8px; font-family:monospace'>
            <p style='color:#4caf50'>VALID      sales_mar.csv</p>
            <p style='color:#4caf50'>VALID      report_q1.csv</p>
            <p style='color:#ef5350'>INVALID    bad_data.csv</p>
        </div>
    </div>
"""))

# %%
# Cell 4 - Complete UI with all principles
# Principles: Error Prevention, Consistency, Feedback, Visibility

from IPython.display import display, HTML

display(HTML("""
    <div style='background:#1e1e2e; padding:20px; max-width:500px'>

        <h3 style='color:white; text-align:center'>CSV File Pipeline</h3>

        <label style='color:#aaaaaa'>FTP Server:</label><br>
        <input value='ftp.example.com'
               style='background:#2e2e3e; color:white; border:none;
                      padding:6px; width:250px; margin:8px 0'>

        <p style='color:#4caf50'>Status: Done!</p>

        <div style='margin:10px 0'>
            <button style='background:#4caf50; color:white; padding:8px 16px;
                    border:none; margin:4px; font-size:13px'>▶ Start</button>
            <button style='background:#ef5350; color:white; padding:8px 16px;
                    border:none; margin:4px; font-size:13px'>■ Stop</button>
            <button style='background:#555555; color:white; padding:8px 16px;
                    border:none; margin:4px; font-size:13px'>↺ Clear</button>
        </div>

        <b style='color:white'>Results</b>
        <div style='background:#2e2e3e; padding:10px; margin-top:8px; font-family:monospace'>
            <p style='color:#4caf50'>VALID      sales_mar.csv</p>
            <p style='color:#4caf50'>VALID      report_q1.csv</p>
            <p style='color:#ef5350'>INVALID    bad_data.csv</p>
        </div>

    </div>
"""))
# Out:
#     <div style='background:#1e1e2e; padding:20px; max-width:500px'>
#
#         <h3 style='color:white; text-align:center'>CSV File Pipeline</h3>
#
#         <label style='color:#aaaaaa'>FTP Server:</label><br>
#         <input value='ftp.example.com'
#                style='background:#2e2e3e; color:white; border:none;
#                       padding:6px; width:250px; margin:8px 0'>
#
#         <p style='color:#4caf50'>Status: Done!</p>
#
#         <div style='margin:10px 0'>
#             <button style='background:#4caf50; color:white; padding:8px 16px;
#                     border:none; margin:4px; font-size:13px'>▶ Start</button>
#             <button style='background:#ef5350; color:white; padding:8px 16px;
#                     border:none; margin:4px; font-size:13px'>■ Stop</button>
#             <button style='background:#555555; color:white; padding:8px 16px;
#                     border:none; margin:4px; font-size:13px'>↺ Clear</button>
#         </div>
#
# ...
